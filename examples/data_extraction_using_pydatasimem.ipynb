# %% [markdown]
# ![image.png](attachment:image.png)
#
# [SiMEM](https://www.simem.co/)

# %% [markdown]
# ## Objetivos de este Notebook
#
# * Explicar cómo se puede consultar el catálogo de conjuntos de datos que se publican en SiMEM.
# * Explicar cómo consultar la información de un conjunto de datos determinado.
# * Demostrar cómo hacer filtros especializados en un conjunto de datos determinado.

# %% [markdown]
# ### Carga del objeto PyDataSimem

# %% [markdown]
# En la siguiente celda se importa el objeto PyDataSimem, que contiene el método para consultar los conjuntos de datos de SiMEM

# %%
import sys
import os
sys.path.append(os.path.abspath('..\src'))
from pydatasimem import PyDataSimem

objeto = PyDataSimem()

# %% [markdown]
# ### Importacion de librerías

# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# ### Consulta para obtener el catálogo de conjuntos de datos

# %% [markdown]
# El catálogo de conjuntos de datos de SiMEM es un conjunto de datos también, por lo tanto cuenta con un DatasetID, el cual es e007fb.
#
# Se hace la consulta para la fecha de hoy

# %%
fecha_hoy = dt.datetime.strftime(dt.date.today() - dt.timedelta(days=1),'%Y-%m-%d')
dataset_id = 'e007fb'

# %%
df_catalogo = objeto.main(dataset_id, start_date=fecha_hoy, end_date=fecha_hoy)
df_catalogo.head()
# Out:
#   idDataset                                nombreConjuntoDatos  \
# 0    ADE905         Panorama energético Corto Plazo Generación
# 1    a704ee  Datos soporte del proceso de liquidación por C...
# 2    d808d4   Energía de Referencia para el Mercado Secundario
# 3    2106b8  Precios y estadísticas de los contratos de con...
# 4    F3A83B  Estadísticas de contratos de Demanda Desconect...
#
#           fechaPublicacion       fechaActualizacion           inicioDato  \
# 0   2023-11-28T12:07:03.03  2024-05-05T19:17:51.437  2023-10-02T00:00:00
# 1  2023-09-28T21:28:06.433   2024-05-06T23:18:50.38  2017-12-01T00:00:00
# 2  2023-09-29T11:01:54.317   2024-05-07T09:45:35.76  2018-12-01T00:00:00
# 3   2023-09-30T10:35:01.19  2024-05-05T06:27:33.627  2020-10-01T00:00:00
# 4  2023-09-30T11:09:06.763  2024-05-07T08:16:51.923  2022-12-01T00:00:00
#
#                finDato            fechaDescarga  \
# 0  2024-05-12T00:00:00                     None
# 1  2024-04-01T00:00:00  2024-02-06T11:57:58.247
# 2  2050-11-30T00:00:00  2024-04-22T14:58:19.537
# 3  2024-04-01T00:00:00                     None
# 4  2024-05-01T00:00:00  2024-05-06T11:54:57.203
#
#                                       urlConexionAPI  \
# 0  https://www.simem.co/backend-files/api/PublicD...
# 1  https://www.simem.co/backend-files/api/PublicD...
# 2  https://www.simem.co/backend-files/api/PublicD...
# 3  https://www.simem.co/backend-files/api/PublicD...
# 4  https://www.simem.co/backend-files/api/PublicD...
#
#                                     urlConjuntoDatos tipoPublicacion
# 0  https://www.simem.co/datadetail/ade905f7-cb05-...         Público
# 1  https://www.simem.co/datadetail/a704eef3-ca1c-...         Público
# 2  https://www.simem.co/datadetail/d808d43d-e3da-...         Público
# 3  https://www.simem.co/datadetail/99686983-57a4-...         Público
# 4  https://www.simem.co/datadetail/f3a83baa-a370-...         Público

# %% [markdown]
# Aquí se obtienen todos los conjuntos de datos disponibles en SiMEM, las columnas se leen de la siguiente manera:
#
# * **idDataset**: Identificador único del conjunto de datos, es el que se utiliza en el objeto PyDataSimem para consultar la información.
# * **nombreConjuntoDatos**: Nombre con el que se encuentra el conjunto de datos en el portal.
# * **fechaPublicacion**: Indica desde cuando existe el el conjunto de datos en SIMEM
# * **fechaActualizacion**: Indica la ultima vez que se actualizó el conjunto de datos
# * **inicioDato**: Indica desde qué fecha contiene información el conjunto de datos
# * **finDato**: Indica hasta cuando contiene información el conjunto de datos
# * **fechaDescarga**: Indica la fecha y hora de la ultima descarga del conjunto de datos
# * **urlConexionAPI**: URL para la conexión a la API
# * **urlConjuntoDatos**: URL para la conexión en el portal SIMEM
# * **tipoPublicacion**: 	Privacidad del conjunto de datos

# %% [markdown]
# ### Consultar información de un conjunto de datos

# %% [markdown]
# Para el ejemplo, se desea consultar la información de la Generación Real del SIN entre la fecha 2024-04-01 y la fecha 2024-04-07. Para esto, buscamos en el catálogo de datos el Dataset ID correspondiente

# %%
df_catalogo.query("nombreConjuntoDatos.str.contains('Generación Real')")
# Out:
#     idDataset                                nombreConjuntoDatos  \
# 208    E17D25  Generación Real y Programada en las Plantas de...
#
#            fechaPublicacion       fechaActualizacion           inicioDato  \
# 208  2023-09-29T10:59:40.38  2024-05-07T08:16:20.267  2013-01-01T00:00:00
#
#                  finDato           fechaDescarga  \
# 208  2024-05-05T00:00:00  2024-04-26T17:46:58.05
#
#                                         urlConexionAPI  \
# 208  https://www.simem.co/backend-files/api/PublicD...
#
#                                       urlConjuntoDatos tipoPublicacion
# 208  https://www.simem.co/datadetail/e17d259d-ffba-...         Público

# %% [markdown]
# Ahora, se definen los parámetros de entrada y se hace la búsqueda de la información.

# %%
dataset_id = 'E17D25'
fecha_inicio = '2024-04-01'
fecha_fin = '2024-04-07'

# %%
df_genreal = objeto.main(dataset_id, fecha_inicio, fecha_fin)
df_genreal.head(10)
# Out:
#         Fecha CodigoPlanta TipoGeneracion TipoClasificacion  \
# 0  2024-04-07         LBR1     Hidraulica        Hidraulica
# 1  2024-04-07         SBA1     Hidraulica        Hidraulica
# 2  2024-04-07         FLRD     Hidraulica        Hidraulica
# 3  2024-04-07         COE1     Hidraulica        Hidraulica
# 4  2024-04-07         LPLO     Hidraulica        Hidraulica
# 5  2024-04-07         GCA1     Hidraulica        Hidraulica
# 6  2024-04-07         ALTG     Hidraulica        Hidraulica
# 7  2024-04-07         3HDG     Hidraulica        Hidraulica
# 8  2024-04-07         2QBW     Hidraulica        Hidraulica
# 9  2024-04-07         SPY1     Hidraulica        Hidraulica
#
#           TipoDespachoRecurso  GeneracionRealEstimada  \
# 0  No Despachado Centralmente            55929.769531
# 1  No Despachado Centralmente            38134.730469
# 2  No Despachado Centralmente           211840.000000
# 3  No Despachado Centralmente            13990.049805
# 4  No Despachado Centralmente            20918.439453
# 5  No Despachado Centralmente                0.000000
# 6  No Despachado Centralmente           146799.437500
# 7  No Despachado Centralmente           218527.656250
# 8  No Despachado Centralmente           277185.843750
# 9  No Despachado Centralmente            38955.000000
#
#    GeneracionProgramadaDespacho  GeneracionProgramadaRedespacho
# 0                       48000.0                           48000
# 1                       40800.0                           40800
# 2                      186000.0                          186000
# 3                       26400.0                           26400
# 4                       19200.0                           19200
# 5                       84000.0                           84000
# 6                      184000.0                          184000
# 7                      412200.0                          412200
# 8                      370000.0                          370000
# 9                       36000.0                           36000

# %% [markdown]
# ### Analizar la información consultada

# %% [markdown]
# De acuerdo con la información que entrega el conjunto de datos de generación real, es posible obtener información, por ejemplo, de cuánto fue la generación real por tipo de generación para cada día de la consulta.

# %%
df_genreal.groupby(['Fecha','TipoGeneracion'])['GeneracionRealEstimada'].sum().reset_index()
# Out:
#          Fecha TipoGeneracion  GeneracionRealEstimada
# 0   2024-04-01    Cogenerador            2.214651e+06
# 1   2024-04-01         Eolica            4.336332e+05
# 2   2024-04-01     Hidraulica            1.172237e+08
# 3   2024-04-01          Solar            9.861245e+06
# 4   2024-04-01        Termica            1.023937e+08
# 5   2024-04-02    Cogenerador            2.160171e+06
# 6   2024-04-02         Eolica            4.439391e+05
# 7   2024-04-02     Hidraulica            1.178135e+08
# 8   2024-04-02          Solar            7.857761e+06
# 9   2024-04-02        Termica            1.015718e+08
# 10  2024-04-03    Cogenerador            2.358129e+06
# 11  2024-04-03         Eolica            4.169753e+05
# 12  2024-04-03     Hidraulica            1.171430e+08
# 13  2024-04-03          Solar            7.001703e+06
# 14  2024-04-03        Termica            1.044829e+08
# 15  2024-04-04    Cogenerador            2.222087e+06
# 16  2024-04-04         Eolica            3.691731e+05
# 17  2024-04-04     Hidraulica            1.174442e+08
# 18  2024-04-04          Solar            5.762751e+06
# 19  2024-04-04        Termica            1.049224e+08
# 20  2024-04-05    Cogenerador            2.050047e+06
# 21  2024-04-05         Eolica            3.862272e+05
# 22  2024-04-05     Hidraulica            1.231985e+08
# 23  2024-04-05          Solar            9.090898e+06
# 24  2024-04-05        Termica            1.025633e+08
# 25  2024-04-06    Cogenerador            2.301905e+06
# 26  2024-04-06         Eolica            4.556597e+05
# 27  2024-04-06     Hidraulica            1.242431e+08
# 28  2024-04-06          Solar            9.818154e+06
# 29  2024-04-06        Termica            9.280124e+07
# 30  2024-04-07    Cogenerador            2.368678e+06
# 31  2024-04-07         Eolica            4.954315e+05
# 32  2024-04-07     Hidraulica            1.087444e+08
# 33  2024-04-07          Solar            1.031783e+07
# 34  2024-04-07        Termica            9.054019e+07
